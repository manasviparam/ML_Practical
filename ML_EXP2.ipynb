# %% [markdown]
# <a href="https://colab.research.google.com/github/manasviparam/ML_Practical/blob/main/ML_EXP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages

sns.set_style("whitegrid")   # optional: gives cleaner-looking charts

# %%
num_cols = ['CGPA', 'AttendancePercent', 'AptitudeTestScore',
            'CodingTestScore', 'SoftSkillsRating', 'Salary Package']

# %%
fig1 = plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis", yticklabels=False)
plt.title("Missingness Heatmap - Placement Prediction Dataset")
plt.xlabel("Columns")
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd # Assuming df is a pandas DataFrame

# Load the DataFrame 'df' from the CSV file
df = pd.read_csv('/content/placement_predict_50k.csv')

# Define num_cols by selecting numerical columns from df
num_cols = df.select_dtypes(include=['number']).columns

fig2, axes = plt.subplots(2, 3, figsize=(15, 8))

# Limit iteration to the number of available subplots (2 rows * 3 columns = 6 plots)
for i, col in enumerate(num_cols[:6]):
    row, colpos = divmod(i, 3)
    sns.histplot(df[col].dropna(), bins=30, kde=True,
                 ax=axes[row, colpos], color='steelblue')
    axes[row, colpos].set_title(f'Distribution of {col}')

plt.tight_layout()

# %%
fig4 = plt.figure(figsize=(10, 8))

numeric_df = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_df.corr()

sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm',
            square=True, linewidths=0.5)
plt.title('Correlation Heatmap - Numerical Features')
plt.tight_layout()

# %%
fig5, axes5 = plt.subplots(2, 3, figsize=(15, 8))

for i, col in enumerate(num_cols[:6]): # Limit to first 6 columns
    row, colpos = divmod(i, 3)
    sns.boxplot(y=df[col], ax=axes5[row, colpos], color='lightcoral')
    axes5[row, colpos].set_title(f'Boxplot of {col}')

plt.tight_layout()

# %%
# 1. Generate and save the PDF cleanly inside the block
with PdfPages('EDA_Report.pdf') as pdf:
    pdf.savefig(fig1)   # Page 1: Missingn Heatmap
    pdf.savefig(fig2)   # Page 2: Six Histograms
    pdf.savefig(fig4)   # Page 3: Correlation Heatmap
    pdf.savefig(fig5)   # Page 4: Boxplots

# %%
files.download('EDA_Report.pdf')
